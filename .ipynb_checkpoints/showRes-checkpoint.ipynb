# %%
import pandas as pd

# %%
N = 500
T = 400
dir_path = 'resultData/'
file_path = dir_path + 'result_' + str(N) + '-' + str(T) + '.csv'
print(file_path)
# Out:
# resultData/result_500-400.csv

# %%
df = pd.read_csv(file_path, float_precision = 2)
df.drop(columns = 'Unnamed: 0', inplace = True)

# %% [markdown]
# compute the error rate $$\frac{\|A - \hat A_i\|}{\| A \|}.$$
# Here $A$ is covariance $\Sigma$ or correlation $R$, and $i$ stands for an estimation method.

# %%
for col in ['Sample', 'Linear Shrinkage', 'Nonlinear Shrinkage', 'Info Band']:
    new_col = col + ' err'
    df[new_col] = df[col] / df['S or R']
df.head()
# Out:
#   group norm type  rho  eta  near factor     S or R     Sample  \
# 0     S       fro  0.8  0.5          0.5  47.622487  24.948132
# 1     R       fro  0.8  0.5          0.5  47.622487  24.824057
# 2     S         2  0.8  0.5          0.5   8.993148   6.791039
# 3     R         2  0.8  0.5          0.5   8.993148   6.461826
# 4     S       fro  0.8  0.5          2.0  47.622487  24.948132
#
#    Linear Shrinkage  Nonlinear Shrinkage  Info Band  Sample err  \
# 0         21.666508            21.088504   7.552335    0.523873
# 1         21.512487            20.978904   6.517629    0.521268
# 2          5.030148             4.688550   1.844382    0.755135
# 3          4.947598             4.630046   1.480413    0.718528
# 4         21.666508            21.088504   9.336700    0.523873
#
#    Linear Shrinkage err  Nonlinear Shrinkage err  Info Band err
# 0              0.454964                 0.442827       0.158588
# 1              0.451730                 0.440525       0.136860
# 2              0.559331                 0.521347       0.205087
# 3              0.550152                 0.514842       0.164616
# 4              0.454964                 0.442827       0.196057

# %%
rho_range = df['rho'].unique()
print(rho_range)
eta_range = df['eta'].unique()
print(eta_range)
near_factor_range = df['near factor'].unique()
print(near_factor_range)
# Out:
# [0.8  0.9  0.95 0.99]
# [0.5 0.8 1. ]
# [0.5 2. ]

# %% [markdown]
# # 3D plot

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np 
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

x=np.array([0.1, 0.3, 0.5, 0.7, 0.9, 1.1, 1.3, 1.5, 1.7, 1.9, 2])
y=np.array([0.57,0.85,0.66,0.84,0.59,0.55,0.61,0.76,0.54,0.55,0.48])

x_new = np.linspace(x.min(), x.max(),500)
y_smooth = make_interp_spline(x, y)(x_new)

plt.plot (x_new,y_smooth)
plt.scatter (x, y)

# %%
tmp = df.set_index(['group', 'norm type', 'rho']).sort_index()

# %% [markdown]
# # See the results in groups

# %%
group = 'R' # change to 'S'
norm_type = '2' # change to other norms, 1 or 2

# %%
tmp = df[(df['group'] == group) & (df['norm type'] == norm_type)]
tmp.drop(columns = ['group', 'norm type'], inplace = True)
# Out:
# C:\Users\lx\AppData\Local\Temp\ipykernel_16908\3106017913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp.drop(columns = ['group', 'norm type'], inplace = True)

# %%
id_cols = ['rho', 'eta', 'near factor']
tmp.set_index(id_cols)
# Out:
#                       S or R  Sample  Linear Shrinkage  Nonlinear Shrinkage  \
# rho  eta near factor
# 0.80 0.5 0.5            8.96    6.89              5.79                 5.54
#          1.0            8.96    6.89              5.79                 5.54
#          2.0            8.96    6.89              5.79                 5.54
#      0.8 0.5            8.96    6.89              5.79                 5.54
#          1.0            8.96    6.89              5.79                 5.54
#          2.0            8.96    6.89              5.79                 5.54
#      1.0 0.5            8.96    6.89              5.79                 5.54
#          1.0            8.96    6.89              5.79                 5.54
#          2.0            8.96    6.89              5.79                 5.54
# 0.90 0.5 0.5           18.65    9.55              7.99                 7.59
#          1.0           18.65    9.55              7.99                 7.59
#          2.0           18.65    9.55              7.99                 7.59
#      0.8 0.5           18.65    9.55              7.99                 7.59
#          1.0           18.65    9.55              7.99                 7.59
#          2.0           18.65    9.55              7.99                 7.59
#      1.0 0.5           18.65    9.55              7.99                 7.59
#          1.0           18.65    9.55              7.99                 7.59
#          2.0           18.65    9.55              7.99                 7.59
# 0.95 0.5 0.5           36.58   11.33             11.63                10.54
#          1.0           36.58   11.33             11.63                10.54
#          2.0           36.58   11.33             11.63                10.54
#      0.8 0.5           36.58   11.33             11.63                10.54
#          1.0           36.58   11.33             11.63                10.54
#          2.0           36.58   11.33             11.63                10.54
#      1.0 0.5           36.58   11.33             11.63                10.54
#          1.0           36.58   11.33             11.63                10.54
#          2.0           36.58   11.33             11.63                10.54
# 0.99 0.5 0.5          114.67   10.13             11.04                10.70
#          1.0          114.67   10.13             11.04                10.70
#          2.0          114.67   10.13             11.04                10.70
#      0.8 0.5          114.67   10.13             11.04                10.70
#          1.0          114.67   10.13             11.04                10.70
#          2.0          114.67   10.13             11.04                10.70
#      1.0 0.5          114.67   10.13             11.04                10.70
#          1.0          114.67   10.13             11.04                10.70
#          2.0          114.67   10.13             11.04                10.70
#
#                       Info Band
# rho  eta near factor
# 0.80 0.5 0.5               7.55
#          1.0               7.53
#          2.0               7.57
#      0.8 0.5               7.54
#          1.0               7.55
#          2.0               7.46
#      1.0 0.5               7.66
#          1.0               7.66
#          2.0               7.66
# 0.90 0.5 0.5              17.12
#          1.0              17.65
#          2.0              17.19
#      0.8 0.5              17.65
#          1.0              17.17
#          2.0              17.65
#      1.0 0.5              17.29
#          1.0              17.65
#          2.0              17.29
# 0.95 0.5 0.5              27.16
#          1.0              28.32
#          2.0              30.06
#      0.8 0.5               5.10
#          1.0              23.23
#          2.0              32.16
#      1.0 0.5               5.96
#          1.0               5.85
#          2.0               6.53
# 0.99 0.5 0.5             109.13
#          1.0             102.59
#          2.0             111.14
#      0.8 0.5               9.62
#          1.0              48.97
#          2.0             106.16
#      1.0 0.5              19.70
#          1.0              20.88
#          2.0              20.48

# %%
# id_cols = id_cols[1:] + [id_cols[0]] # permutation

# %%
df.sort_index(inplace = True)

# %%
with open('latex/Res.json', 'w') as f:
    f.write(df.to_latex())
# Out:
# C:\Users\lx\AppData\Local\Temp\ipykernel_15088\2024524132.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(df.to_latex())

# %%
's'+str(100)
# Out:
# 's100'
