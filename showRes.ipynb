# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')
df = df.set_index(['group', 'norm type', 'rho', 'eta', 'near factor'])
df.drop(columns = 'Unnamed: 0', inplace = True)
df.head(10)
# Out:
#                          S  Sample Cov  Linear Shrinkage Cov  \
# rho eta near factor
# 0.8 0.5 0.5          30.02       20.05                 15.96
#         1.0          30.02       20.87                 16.03
#         2.0          30.02       20.41                 16.05
#     0.8 0.5          30.02       20.20                 16.21
#         1.0          30.02       19.19                 16.59
#         2.0          30.02       20.39                 16.01
#     1.0 0.5          30.02       20.16                 15.95
#         1.0          30.02       20.77                 15.76
#         2.0          30.02       19.11                 16.21
# 0.9 0.5 0.5          43.13       21.78                 18.29
#
#                      Nonlinear Shrinkage Cov  Info Band Cov      R  \
# rho eta near factor
# 0.8 0.5 0.5                            15.63          25.24  30.02
#         1.0                            15.77          16.68  30.02
# ...

# %%
with open('Res.json', 'w') as f:
    f.write(df.to_latex())
# Out:
# C:\Users\lx\AppData\Local\Temp\ipykernel_14652\1102988224.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(df.to_latex())
