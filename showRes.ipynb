# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')
df.drop(columns = 'Unnamed: 0', inplace = True)
# df.head(10)

# %%
df.set_index(['group', 'norm type', 'rho', 'eta', 'near factor'], inplace = True)
# df.head(30)

# %%
df.sort_index(inplace = True)
df.head(30)
# Out:
#                                       S or R  Sample  Linear Shrinkage  \
# group norm type rho  eta near factor
# R     1         0.80 0.5 0.5            9.00   19.00             14.46
#                          1.0            9.00   19.76             14.85
#                          2.0            9.00   21.03             15.73
#                      0.8 0.5            9.00   20.46             15.41
#                          1.0            9.00   21.93             15.89
#                          2.0            9.00   21.72             14.49
#                      1.0 0.5            9.00   20.37             15.28
#                          1.0            9.00   19.81             15.01
#                          2.0            9.00   23.47             17.26
#                 0.90 0.5 0.5           19.00   24.15             20.32
#                          1.0           19.00   21.37             20.67
#                          2.0           19.00   20.39             19.69
# ...

# %%
with open('Res.json', 'w') as f:
    f.write(df.to_latex())
# Out:
# C:\Users\lx\AppData\Local\Temp\ipykernel_8188\1102988224.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   f.write(df.to_latex())
