# %%
import sys, os
sys.path.append(os.getcwd() + '\..')
import pandas as pd
import numpy as np
from my_api import *
import matplotlib.pyplot as plt
# Out:
# 0.9
# 12.685905874921438 8.685905874921438
# 0.5
# 15.15749916396364 11.15749916396364
# d:\BaiduSyncdisk\Project\Co_simu_3\code_Bernoulli\..\gen_S.py:141: ComplexWarning: Casting complex values to real discards the imaginary part
#   S = S.astype(np.float64)

# %%
id = pd.MultiIndex.from_product([['fro', 2], [100, 300, 500]])
df = pd.DataFrame(index = id)

# %%
T = 300
rela = False
cov_str = 'Bernoulli'

# %%
simu_str = 'lx_band'
data_path = '../data_Cai2_Bernoulli/'
for N in [100, 300, 500]:
    if cov_str == 'Bernoulli':
        S = gen_S_Bernoulli(N = N, seed = 0, probB = 20 / N)
    else:
        raise Exception
    
    for ord in ['fro', 2]:
        normS = np.linalg.norm(S, ord)
        
        for eta in [0.5, 0.8, 1]:
            cov_params = [cov_str]
            simu_params = [simu_str, eta]
            file_name = f"{ord},S,{N},{T},{cov_params},{simu_params}.txt"
            file_name = data_path + file_name
            data = np.loadtxt(file_name)

            col = str(simu_params)
            if col not in df.columns:
                df[col] = None
            if not rela:
                data *= normS # absolute error
            df[col][ord, N] = f"{data.mean() :.2f}({data.std() :.2f})"
df
# Out:
#         ['lx_band', 0.5] ['lx_band', 0.8] ['lx_band', 1]
# fro 100      28.82(0.84)      23.45(0.62)    21.48(0.57)
#     300      51.38(0.77)      43.09(0.71)    40.05(0.93)
#     500      64.72(0.79)      52.96(0.63)    49.88(0.67)
# 2   100       7.55(0.93)       5.20(0.41)     4.79(0.34)
#     300       8.41(0.49)       5.96(0.30)     5.63(0.33)
#     500       7.66(0.41)       5.45(0.20)     5.32(0.21)

# %%
simu_str = 'LSRthreshold'
data_path = '../data_Cai2_Bernoulli/'
num_cv = 50

for N in [100, 300, 500]:
    if cov_str == 'Bernoulli':
        S = gen_S_Bernoulli(N = N, seed = 0, probB = 20 / N)
    else:
        raise Exception
    
    for ord in ['fro', 2]:
        normS = np.linalg.norm(S, ord)
        
        for tau in [0.2]:
            # for prob in [0.99, 0.9, 1]:
            #     for qrob in [0, 0.01, 0.1]:
            for prob in [1, 0.99]:
                for qrob in [0, 0.01]:
                    cov_params = [cov_str]
                    simu_params = [simu_str, tau, prob, qrob, 'brute', num_cv]
                    file_name = f"{ord},S,{N},{T},{cov_params},{simu_params}.txt"
                    file_name = data_path + file_name
                    
                    try:
                        data = np.loadtxt(file_name)
                    except FileNotFoundError:
                        continue

                    col = str(simu_params)
                    if col not in df.columns:
                        df[col] = None
                    if not rela:
                        data *= normS # absolute error
                        df[col][ord, N] = f"{data.mean() :.2f}({data.std() :.2f})"
df
# Out:
#         ['lx_band', 0.5] ['lx_band', 0.8] ['lx_band', 1]  \
# fro 100      28.82(0.84)      23.45(0.62)    21.48(0.57)
#     300      51.38(0.77)      43.09(0.71)    40.05(0.93)
#     500      64.72(0.79)      52.96(0.63)    49.88(0.67)
# 2   100       7.55(0.93)       5.20(0.41)     4.79(0.34)
#     300       8.41(0.49)       5.96(0.30)     5.63(0.33)
#     500       7.66(0.41)       5.45(0.20)     5.32(0.21)
#
#         ['LSRthreshold', 0.2, 1, 0, 'brute', 50]
# fro 100                              26.74(2.24)
#     300                              70.10(6.31)
#     500                            111.10(12.04)
# 2   100                               7.05(0.89)
#     300                              12.08(1.55)
#     500                              15.96(2.20)

# %%
simu_str = '' # to be determined
data_path = '../data_Cai2_Bernoulli/'

for N in [100, 300, 500]:
    if cov_str == 'Bernoulli':
        S = gen_S_Bernoulli(N = N, seed = 0, probB = 20 / N)
    else:
        raise Exception
    
    for ord in ['fro', 2]:
        normS = np.linalg.norm(S, ord)

        # from Cai2011_other import Other_Methods
        for simu_str in ['Sample', 'Soft Threshold', 'Hard Threshold', 'Linear Shrink', 'Nonlinear Shrink']: 
            cov_params = [cov_str]
            simu_params = [simu_str]
            file_name = f"{ord},S,{N},{T},{cov_params},{simu_params}.txt"
            file_name = data_path + file_name
            try:
                data = np.loadtxt(file_name)
            except FileNotFoundError:
                continue

            col = str(*simu_params)
            if col not in df.columns:
                df[col] = None
            
            if not rela:
                data *= normS # absolute error
            df[col][ord, N] = f"{data.mean() :.2f}({data.std() :.2f})"
df
# Out:
#         ['lx_band', 0.5] ['lx_band', 0.8] ['lx_band', 1]  \
# fro 100      28.82(0.84)      23.45(0.62)    21.48(0.57)
#     300      51.38(0.77)      43.09(0.71)    40.05(0.93)
#     500      64.72(0.79)      52.96(0.63)    49.88(0.67)
# 2   100       7.55(0.93)       5.20(0.41)     4.79(0.34)
#     300       8.41(0.49)       5.96(0.30)     5.63(0.33)
#     500       7.66(0.41)       5.45(0.20)     5.32(0.21)
#
#         ['LSRthreshold', 0.2, 1, 0, 'brute', 50]        Sample Soft Threshold  \
# fro 100                              26.74(2.24)   42.35(0.86)    37.19(0.87)
#     300                              70.10(6.31)  136.49(0.97)   107.80(1.04)
#     500                            111.10(12.04)  225.35(1.04)   169.52(1.17)
# 2   100                               7.05(0.89)   11.75(1.10)     9.93(0.88)
#     300                              12.08(1.55)   25.60(0.84)    19.31(0.72)
#     500                              15.96(2.20)   35.69(0.84)    25.62(0.69)
#
#         Hard Threshold Linear Shrink Nonlinear Shrink
# fro 100    42.32(0.86)   29.25(0.47)      27.19(0.55)
#     300   136.03(0.98)   61.69(0.14)             None
#     500   224.11(1.06)   83.04(0.10)             None
# 2   100    11.74(1.11)   11.24(1.24)       9.54(1.64)
#     300    25.44(0.84)   15.43(0.44)             None
#     500    35.33(0.81)   16.41(0.28)             None

# %%
df
# Out:
#         ['lx_band', 0.5] ['lx_band', 0.8] ['lx_band', 1]  \
# fro 100      28.82(0.84)      23.45(0.62)    21.48(0.57)
#     300      51.38(0.77)      43.09(0.71)    40.05(0.93)
#     500      64.72(0.79)      52.96(0.63)    49.88(0.67)
# 2   100       7.55(0.93)       5.20(0.41)     4.79(0.34)
#     300       8.41(0.49)       5.96(0.30)     5.63(0.33)
#     500       7.66(0.41)       5.45(0.20)     5.32(0.21)
#
#         ['LSRthreshold', 0.2, 1, 0, 'brute', 50]        Sample Soft Threshold  \
# fro 100                              26.74(2.24)   42.35(0.86)    37.19(0.87)
#     300                              70.10(6.31)  136.49(0.97)   107.80(1.04)
#     500                            111.10(12.04)  225.35(1.04)   169.52(1.17)
# 2   100                               7.05(0.89)   11.75(1.10)     9.93(0.88)
#     300                              12.08(1.55)   25.60(0.84)    19.31(0.72)
#     500                              15.96(2.20)   35.69(0.84)    25.62(0.69)
#
#         Hard Threshold Linear Shrink Nonlinear Shrink
# fro 100    42.32(0.86)   29.25(0.47)      27.19(0.55)
#     300   136.03(0.98)   61.69(0.14)             None
#     500   224.11(1.06)   83.04(0.10)             None
# 2   100    11.74(1.11)   11.24(1.24)       9.54(1.64)
#     300    25.44(0.84)   15.43(0.44)             None
#     500    35.33(0.81)   16.41(0.28)             None

# %%
new_cols = []
for col in df.columns:
    try:
        col = eval(col)
    except Exception:
        pass

    if type(col) == str:
        new_col = col
    elif 'lx_band' in col:
        eta = col[1]
        new_col = fr'Augmented Band ($\eta={eta}$)'
    elif 'LSRthreshold' in col or 'thG' in col:
        formal_name = {'LSRthreshold': 'Augmented Threshold', 'thG': 'Threshold then Augment'}[col[0]]
        t, p, q = col[1:-2]
        new_col = fr'{formal_name} ($\tau={t}, p={p}, q={q}$)' # The r in fr, means raw string. Otherwise I should write \\tau instead of \tau.
    new_cols.append(new_col)
df.columns = new_cols
df.head(1)
# Out:
#         Augmented Band ($\eta=0.5$) Augmented Band ($\eta=0.8$)  \
# fro 100                 28.82(0.84)                 23.45(0.62)
#
#         Augmented Band ($\eta=1$) Augmented Threshold ($\tau=0.2, p=1, q=0$)  \
# fro 100               21.48(0.57)                                26.74(2.24)
#
#               Sample Soft Threshold Hard Threshold Linear Shrink  \
# fro 100  42.35(0.86)    37.19(0.87)    42.32(0.86)   29.25(0.47)
#
#         Nonlinear Shrink
# fro 100      27.19(0.55)

# %%
buf = '../latex/' + cov_str + '.tex'
caption = cov_str

with pd.option_context("max_colwidth", 1000, 'display.width', 50):
    df.to_latex(buf = buf, 
                index = True, na_rep = ' ', sparsify = True, 
             column_format = 'll|' + 'p{2cm}' * df.shape[1], 
             longtable = False, 
             escape = False, encoding = 'utf-8', 
             caption = caption, label = "my label", 
             position = 'htbp')
# escape参数，防止字符被转换使得我设的数学模式被破坏
# Out:
# C:\Users\lx\AppData\Local\Temp\ipykernel_1628\2522360471.py:5: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   df.to_latex(buf = buf,

# %%
pd.get_option('display.width')
# Out:
# 80

# %%
lines = []

with open(buf, 'r') as fp:
    lines = fp.readlines()

s1 = r'\resizebox{\linewidth}{!}{' + '\n'
s2 = r'}' + '\n'
lines.insert(4, s1)
lines.insert(-1, s2)

with open(buf[:-4] + '_processed' + '.tex', 'w') as fp:
    fp.writelines(lines)
        # if not write_flag:
        #     if r'begin{tabular}' in line:
